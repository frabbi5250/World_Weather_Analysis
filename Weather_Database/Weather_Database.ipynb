# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 733

# %%
# Import the requests library.
import requests

# Import the time library.
import time

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hailar
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | kamenka
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | eureka
# Processing Record 8 of Set 1 | esperance
# Processing Record 9 of Set 1 | port lincoln
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 1 | taltal
# Processing Record 13 of Set 1 | rosetta
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | olinda
# Processing Record 16 of Set 1 | moses lake
# Processing Record 17 of Set 1 | brody
# Processing Record 18 of Set 1 | rio verde de mato grosso
# Processing Record 19 of Set 1 | egvekinot
# Processing Record 20 of Set 1 | zyryanskoye
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 1 | matay
# Processing Record 24 of Set 1 | tasiilaq
# Processing Record 25 of Set 1 | hay river
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | karratha
# Processing Record 28 of Set 1 | hermagor
# Processing Record 29 of Set 1 | dunedin
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | saint-joseph
# Processing Record 32 of Set 1 | bubaque
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | gurgan
# City not found. Skipping...
# Processing Record 35 of Set 1 | burlington
# Processing Record 36 of Set 1 | alice springs
# Processing Record 37 of Set 1 | sioux lookout
# Processing Record 38 of Set 1 | iranshahr
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | khorixas
# Processing Record 43 of Set 1 | igrim
# Processing Record 44 of Set 1 | cidreira
# Processing Record 45 of Set 1 | rovaniemi
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | paamiut
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | zolotinka
# City not found. Skipping...
# Processing Record 2 of Set 2 | warrnambool
# Processing Record 3 of Set 2 | khudumelapye
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | cap-aux-meules
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | half moon bay
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | scarborough
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | tautira
# Processing Record 12 of Set 2 | arlit
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 16 of Set 2 | alyangula
# Processing Record 17 of Set 2 | le port
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 | athabasca
# Processing Record 20 of Set 2 | bandar-e anzali
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | aklavik
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 2 | nyurba
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | lucea
# Processing Record 31 of Set 2 | padang
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | nishihara
# Processing Record 34 of Set 2 | chumikan
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | nisia floresta
# Processing Record 37 of Set 2 | faanui
# Processing Record 38 of Set 2 | bonthe
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | bandarbeyla
# Processing Record 41 of Set 2 | cherskiy
# Processing Record 42 of Set 2 | sitka
# Processing Record 43 of Set 2 | bareli
# Processing Record 44 of Set 2 | price
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | puerto escondido
# Processing Record 48 of Set 2 | sao filipe
# Processing Record 49 of Set 2 | saint anthony
# Processing Record 50 of Set 2 | srivardhan
# Processing Record 1 of Set 3 | fortuna
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 3 | nanortalik
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | quatre cocos
# Processing Record 7 of Set 3 | yurla
# Processing Record 8 of Set 3 | lompoc
# Processing Record 9 of Set 3 | cape town
# Processing Record 10 of Set 3 | riyadh
# Processing Record 11 of Set 3 | puerto baquerizo moreno
# Processing Record 12 of Set 3 | lavrentiya
# Processing Record 13 of Set 3 | te anau
# Processing Record 14 of Set 3 | comodoro rivadavia
# Processing Record 15 of Set 3 | norman wells
# Processing Record 16 of Set 3 | cape girardeau
# Processing Record 17 of Set 3 | saint george
# Processing Record 18 of Set 3 | broken hill
# Processing Record 19 of Set 3 | la maddalena
# Processing Record 20 of Set 3 | umm bab
# Processing Record 21 of Set 3 | sena madureira
# Processing Record 22 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 3 | kerrville
# Processing Record 24 of Set 3 | yulara
# Processing Record 25 of Set 3 | isangel
# Processing Record 26 of Set 3 | bowen
# Processing Record 27 of Set 3 | nicoya
# Processing Record 28 of Set 3 | atuona
# Processing Record 29 of Set 3 | goderich
# Processing Record 30 of Set 3 | sao jose da coroa grande
# Processing Record 31 of Set 3 | ixtapa
# Processing Record 32 of Set 3 | macamic
# Processing Record 33 of Set 3 | roma
# Processing Record 34 of Set 3 | komsomolskiy
# Processing Record 35 of Set 3 | ca mau
# Processing Record 36 of Set 3 | nurota
# Processing Record 37 of Set 3 | acapulco
# Processing Record 38 of Set 3 | myre
# Processing Record 39 of Set 3 | petatlan
# Processing Record 40 of Set 3 | labuhan
# Processing Record 41 of Set 3 | luderitz
# Processing Record 42 of Set 3 | camacha
# Processing Record 43 of Set 3 | kant
# Processing Record 44 of Set 3 | araouane
# Processing Record 45 of Set 3 | muros
# Processing Record 46 of Set 3 | hastings
# Processing Record 47 of Set 3 | vardo
# Processing Record 48 of Set 3 | touros
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | erenhot
# Processing Record 1 of Set 4 | taoudenni
# Processing Record 2 of Set 4 | floro
# Processing Record 3 of Set 4 | hobart
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | cap malheureux
# Processing Record 6 of Set 4 | alta floresta
# Processing Record 7 of Set 4 | kahului
# Processing Record 8 of Set 4 | sambava
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | dano
# Processing Record 12 of Set 4 | srednekolymsk
# Processing Record 13 of Set 4 | merauke
# Processing Record 14 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 4 | torbay
# Processing Record 16 of Set 4 | ust-ishim
# Processing Record 17 of Set 4 | awbari
# Processing Record 18 of Set 4 | gornja tuzla
# Processing Record 19 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 4 | klaksvik
# Processing Record 21 of Set 4 | cayenne
# Processing Record 22 of Set 4 | shingu
# Processing Record 23 of Set 4 | wajima
# Processing Record 24 of Set 4 | hofn
# Processing Record 25 of Set 4 | la ronge
# Processing Record 26 of Set 4 | bilma
# Processing Record 27 of Set 4 | atlantic city
# Processing Record 28 of Set 4 | mao
# Processing Record 29 of Set 4 | castro
# Processing Record 30 of Set 4 | portland
# Processing Record 31 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 4 | wattegama
# Processing Record 33 of Set 4 | skibbereen
# Processing Record 34 of Set 4 | senador jose porfirio
# Processing Record 35 of Set 4 | znamenskoye
# Processing Record 36 of Set 4 | shepsi
# Processing Record 37 of Set 4 | butaritari
# Processing Record 38 of Set 4 | montepuez
# Processing Record 39 of Set 4 | hambantota
# Processing Record 40 of Set 4 | vila velha
# Processing Record 41 of Set 4 | nome
# Processing Record 42 of Set 4 | ada
# Processing Record 43 of Set 4 | magistralnyy
# Processing Record 44 of Set 4 | palu
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | beihai
# Processing Record 47 of Set 4 | altay
# Processing Record 48 of Set 4 | bambous virieux
# Processing Record 49 of Set 4 | logrono
# Processing Record 50 of Set 4 | caxito
# Processing Record 1 of Set 5 | kavieng
# Processing Record 2 of Set 5 | rothenbach
# Processing Record 3 of Set 5 | nemuro
# Processing Record 4 of Set 5 | lorengau
# Processing Record 5 of Set 5 | remontnoye
# Processing Record 6 of Set 5 | ilulissat
# Processing Record 7 of Set 5 | lata
# Processing Record 8 of Set 5 | san patricio
# Processing Record 9 of Set 5 | olafsvik
# Processing Record 10 of Set 5 | dali
# Processing Record 11 of Set 5 | conakry
# Processing Record 12 of Set 5 | ancud
# Processing Record 13 of Set 5 | sorland
# Processing Record 14 of Set 5 | teya
# Processing Record 15 of Set 5 | killybegs
# Processing Record 16 of Set 5 | port washington
# Processing Record 17 of Set 5 | provideniya
# Processing Record 18 of Set 5 | charleston
# Processing Record 19 of Set 5 | abnub
# Processing Record 20 of Set 5 | sept-iles
# Processing Record 21 of Set 5 | katsuura
# Processing Record 22 of Set 5 | ngunguru
# Processing Record 23 of Set 5 | broome
# Processing Record 24 of Set 5 | sinop
# Processing Record 25 of Set 5 | arraial do cabo
# Processing Record 26 of Set 5 | artvin
# Processing Record 27 of Set 5 | narsaq
# Processing Record 28 of Set 5 | henties bay
# Processing Record 29 of Set 5 | ust-kuyga
# Processing Record 30 of Set 5 | zhigansk
# Processing Record 31 of Set 5 | juneau
# Processing Record 32 of Set 5 | oistins
# Processing Record 33 of Set 5 | madison heights
# Processing Record 34 of Set 5 | ostrovnoy
# Processing Record 35 of Set 5 | geraldton
# Processing Record 36 of Set 5 | balikpapan
# Processing Record 37 of Set 5 | conde
# Processing Record 38 of Set 5 | codrington
# Processing Record 39 of Set 5 | virar
# Processing Record 40 of Set 5 | yuanping
# Processing Record 41 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 5 | tombouctou
# Processing Record 43 of Set 5 | guerrero negro
# Processing Record 44 of Set 5 | buenos aires
# Processing Record 45 of Set 5 | flin flon
# Processing Record 46 of Set 5 | adrar
# Processing Record 47 of Set 5 | dukat
# Processing Record 48 of Set 5 | pacific grove
# Processing Record 49 of Set 5 | narasannapeta
# Processing Record 50 of Set 5 | newcastle
# Processing Record 1 of Set 6 | riviere-au-renard
# Processing Record 2 of Set 6 | saint-pierre
# Processing Record 3 of Set 6 | morehead
# Processing Record 4 of Set 6 | pevek
# Processing Record 5 of Set 6 | gold coast
# Processing Record 6 of Set 6 | barka kana
# Processing Record 7 of Set 6 | harper
# Processing Record 8 of Set 6 | iquitos
# Processing Record 9 of Set 6 | moose factory
# Processing Record 10 of Set 6 | tiarei
# Processing Record 11 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | mogadishu
# Processing Record 13 of Set 6 | avera
# Processing Record 14 of Set 6 | laurel
# Processing Record 15 of Set 6 | ambulu
# Processing Record 16 of Set 6 | lahat
# Processing Record 17 of Set 6 | victoria
# Processing Record 18 of Set 6 | kirkuk
# Processing Record 19 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 6 | kimbe
# Processing Record 21 of Set 6 | coihueco
# Processing Record 22 of Set 6 | sumbe
# Processing Record 23 of Set 6 | svetlogorsk
# Processing Record 24 of Set 6 | porto novo
# Processing Record 25 of Set 6 | bakchar
# Processing Record 26 of Set 6 | hami
# Processing Record 27 of Set 6 | warwick
# Processing Record 28 of Set 6 | port augusta
# Processing Record 29 of Set 6 | lethem
# Processing Record 30 of Set 6 | tuatapere
# Processing Record 31 of Set 6 | jingcheng
# Processing Record 32 of Set 6 | billings
# Processing Record 33 of Set 6 | fasa
# Processing Record 34 of Set 6 | port elizabeth
# Processing Record 35 of Set 6 | longyearbyen
# Processing Record 36 of Set 6 | papayal
# Processing Record 37 of Set 6 | dingle
# Processing Record 38 of Set 6 | leningradskiy
# Processing Record 39 of Set 6 | sagua la grande
# Processing Record 40 of Set 6 | dikson
# Processing Record 41 of Set 6 | guaruja
# Processing Record 42 of Set 6 | bairiki
# Processing Record 43 of Set 6 | kaitangata
# Processing Record 44 of Set 6 | constitucion
# Processing Record 45 of Set 6 | san jose
# Processing Record 46 of Set 6 | maldonado
# Processing Record 47 of Set 6 | weyburn
# Processing Record 48 of Set 6 | cordoba
# Processing Record 49 of Set 6 | jinxiang
# Processing Record 50 of Set 6 | urucui
# Processing Record 1 of Set 7 | damietta
# Processing Record 2 of Set 7 | coquimbo
# Processing Record 3 of Set 7 | san carlos de bariloche
# Processing Record 4 of Set 7 | souillac
# Processing Record 5 of Set 7 | kasra
# City not found. Skipping...
# Processing Record 6 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 7 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 8 of Set 7 | odweyne
# Processing Record 9 of Set 7 | college
# Processing Record 10 of Set 7 | sorong
# Processing Record 11 of Set 7 | balabac
# Processing Record 12 of Set 7 | villarrica
# Processing Record 13 of Set 7 | varhaug
# Processing Record 14 of Set 7 | cabo san lucas
# Processing Record 15 of Set 7 | vostok
# Processing Record 16 of Set 7 | sao joao da barra
# Processing Record 17 of Set 7 | leshukonskoye
# Processing Record 18 of Set 7 | camacupa
# Processing Record 19 of Set 7 | namatanai
# Processing Record 20 of Set 7 | lisakovsk
# Processing Record 21 of Set 7 | mehamn
# Processing Record 22 of Set 7 | mangan
# Processing Record 23 of Set 7 | lodja
# Processing Record 24 of Set 7 | talnakh
# Processing Record 25 of Set 7 | fort saint james
# Processing Record 26 of Set 7 | qaqortoq
# Processing Record 27 of Set 7 | luz
# Processing Record 28 of Set 7 | staryy nadym
# Processing Record 29 of Set 7 | dongying
# Processing Record 30 of Set 7 | kruisfontein
# Processing Record 31 of Set 7 | sabang
# Processing Record 32 of Set 7 | ossora
# Processing Record 33 of Set 7 | smithers
# Processing Record 34 of Set 7 | great yarmouth
# Processing Record 35 of Set 7 | sobradinho
# Processing Record 36 of Set 7 | chornoliztsi
# Processing Record 37 of Set 7 | omsukchan
# Processing Record 38 of Set 7 | tikri
# Processing Record 39 of Set 7 | alibag
# Processing Record 40 of Set 7 | casablanca
# Processing Record 41 of Set 7 | bull savanna
# Processing Record 42 of Set 7 | lubango
# Processing Record 43 of Set 7 | abha
# Processing Record 44 of Set 7 | port moresby
# Processing Record 45 of Set 7 | bajo baudo
# City not found. Skipping...
# Processing Record 46 of Set 7 | anadyr
# Processing Record 47 of Set 7 | kurumkan
# Processing Record 48 of Set 7 | rosita
# Processing Record 49 of Set 7 | huarmey
# Processing Record 50 of Set 7 | bulancak
# Processing Record 1 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 8 | bayeux
# Processing Record 3 of Set 8 | haines junction
# Processing Record 4 of Set 8 | etaples
# Processing Record 5 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 8 | rio grande
# Processing Record 7 of Set 8 | houma
# Processing Record 8 of Set 8 | oudtshoorn
# Processing Record 9 of Set 8 | mingshui
# Processing Record 10 of Set 8 | tyukhtet
# Processing Record 11 of Set 8 | biak
# Processing Record 12 of Set 8 | lahaina
# Processing Record 13 of Set 8 | gueret
# Processing Record 14 of Set 8 | sur
# Processing Record 15 of Set 8 | amapa
# Processing Record 16 of Set 8 | elban
# Processing Record 17 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 18 of Set 8 | peniche
# Processing Record 19 of Set 8 | estelle
# Processing Record 20 of Set 8 | severo-kurilsk
# Processing Record 21 of Set 8 | clyde river
# Processing Record 22 of Set 8 | surt
# Processing Record 23 of Set 8 | muika
# City not found. Skipping...
# Processing Record 24 of Set 8 | korla
# Processing Record 25 of Set 8 | fairbanks
# Processing Record 26 of Set 8 | mitsamiouli
# Processing Record 27 of Set 8 | atar
# Processing Record 28 of Set 8 | pemangkat
# Processing Record 29 of Set 8 | phan thiet
# Processing Record 30 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 8 | zarate
# Processing Record 32 of Set 8 | chernyshevskiy
# Processing Record 33 of Set 8 | bol
# Processing Record 34 of Set 8 | lagoa
# Processing Record 35 of Set 8 | soe
# Processing Record 36 of Set 8 | ishigaki
# Processing Record 37 of Set 8 | zyryanka
# Processing Record 38 of Set 8 | cabedelo
# Processing Record 39 of Set 8 | sakaiminato
# Processing Record 40 of Set 8 | san lorenzo
# Processing Record 41 of Set 8 | san alberto
# Processing Record 42 of Set 8 | manica
# Processing Record 43 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 44 of Set 8 | rudnogorsk
# Processing Record 45 of Set 8 | palasa
# Processing Record 46 of Set 8 | caravelas
# Processing Record 47 of Set 8 | nuuk
# Processing Record 48 of Set 8 | yar-sale
# Processing Record 49 of Set 8 | lyngseidet
# Processing Record 50 of Set 8 | pyapon
# Processing Record 1 of Set 9 | pinega
# Processing Record 2 of Set 9 | mendi
# Processing Record 3 of Set 9 | tir pol
# City not found. Skipping...
# Processing Record 4 of Set 9 | halifax
# Processing Record 5 of Set 9 | inuvik
# Processing Record 6 of Set 9 | bathsheba
# Processing Record 7 of Set 9 | alofi
# Processing Record 8 of Set 9 | tiznit
# Processing Record 9 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 9 | sherbakul
# Processing Record 11 of Set 9 | yichun
# Processing Record 12 of Set 9 | ziro
# Processing Record 13 of Set 9 | alakurtti
# Processing Record 14 of Set 9 | nara
# Processing Record 15 of Set 9 | saint-augustin
# Processing Record 16 of Set 9 | pathein
# Processing Record 17 of Set 9 | verkhoyansk
# Processing Record 18 of Set 9 | vanimo
# Processing Record 19 of Set 9 | boa vista
# Processing Record 20 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 9 | vilhena
# Processing Record 22 of Set 9 | vestmanna
# Processing Record 23 of Set 9 | georgiyevka
# Processing Record 24 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 25 of Set 9 | tessalit
# Processing Record 26 of Set 9 | wynyard
# Processing Record 27 of Set 9 | harrisonburg
# Processing Record 28 of Set 9 | mount gambier
# Processing Record 29 of Set 9 | tateyama
# Processing Record 30 of Set 9 | tubuala
# Processing Record 31 of Set 9 | mezhdurechensk
# Processing Record 32 of Set 9 | ponta do sol
# Processing Record 33 of Set 9 | bazaliya
# Processing Record 34 of Set 9 | havelock
# Processing Record 35 of Set 9 | bemidji
# Processing Record 36 of Set 9 | kauswagan
# Processing Record 37 of Set 9 | mar del plata
# Processing Record 38 of Set 9 | shimoda
# Processing Record 39 of Set 9 | luganville
# Processing Record 40 of Set 9 | namibe
# Processing Record 41 of Set 9 | chuy
# Processing Record 42 of Set 9 | kavaratti
# Processing Record 43 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 9 | neftcala
# Processing Record 46 of Set 9 | voh
# Processing Record 47 of Set 9 | port hardy
# Processing Record 48 of Set 9 | mandera
# Processing Record 49 of Set 9 | bereznik
# Processing Record 50 of Set 9 | ronne
# Processing Record 1 of Set 10 | rafaela
# Processing Record 2 of Set 10 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 10 | maarianhamina
# Processing Record 4 of Set 10 | mangrol
# Processing Record 5 of Set 10 | monte carmelo
# Processing Record 6 of Set 10 | los llanos de aridane
# Processing Record 7 of Set 10 | naryan-mar
# Processing Record 8 of Set 10 | dakar
# Processing Record 9 of Set 10 | newnan
# Processing Record 10 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 10 | uray
# Processing Record 12 of Set 10 | vallenar
# Processing Record 13 of Set 10 | ahuimanu
# Processing Record 14 of Set 10 | necochea
# Processing Record 15 of Set 10 | gigmoto
# Processing Record 16 of Set 10 | cockburn town
# Processing Record 17 of Set 10 | bjerkvik
# Processing Record 18 of Set 10 | rafsanjan
# Processing Record 19 of Set 10 | niono
# Processing Record 20 of Set 10 | harrison
# Processing Record 21 of Set 10 | morondava
# Processing Record 22 of Set 10 | artyom
# Processing Record 23 of Set 10 | westport
# Processing Record 24 of Set 10 | iqaluit
# Processing Record 25 of Set 10 | saint-georges
# Processing Record 26 of Set 10 | impfondo
# Processing Record 27 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 28 of Set 10 | zhezkazgan
# Processing Record 29 of Set 10 | beloye
# Processing Record 30 of Set 10 | asau
# Processing Record 31 of Set 10 | lithakia
# Processing Record 32 of Set 10 | pavelets
# Processing Record 33 of Set 10 | champerico
# Processing Record 34 of Set 10 | tulum
# Processing Record 35 of Set 10 | lujan
# Processing Record 36 of Set 10 | kolbermoor
# Processing Record 37 of Set 10 | laredo
# Processing Record 38 of Set 10 | chicama
# Processing Record 39 of Set 10 | manacapuru
# Processing Record 40 of Set 10 | mabay
# Processing Record 41 of Set 10 | mayskiy
# Processing Record 42 of Set 10 | montes altos
# Processing Record 43 of Set 10 | rodrigues alves
# Processing Record 44 of Set 10 | kanakapura
# Processing Record 45 of Set 10 | safranbolu
# Processing Record 46 of Set 10 | gimbi
# Processing Record 47 of Set 10 | hun
# Processing Record 48 of Set 10 | airai
# Processing Record 49 of Set 10 | brigantine
# Processing Record 50 of Set 10 | umm lajj
# Processing Record 1 of Set 11 | balkhash
# Processing Record 2 of Set 11 | wuwei
# Processing Record 3 of Set 11 | ribas do rio pardo
# Processing Record 4 of Set 11 | kewanee
# Processing Record 5 of Set 11 | erdenet
# Processing Record 6 of Set 11 | plyussa
# Processing Record 7 of Set 11 | orshanka
# Processing Record 8 of Set 11 | faro
# Processing Record 9 of Set 11 | husavik
# Processing Record 10 of Set 11 | el alto
# Processing Record 11 of Set 11 | kandrian
# Processing Record 12 of Set 11 | krasnoshchekovo
# Processing Record 13 of Set 11 | gat
# Processing Record 14 of Set 11 | hongjiang
# Processing Record 15 of Set 11 | spring valley
# Processing Record 16 of Set 11 | college park
# Processing Record 17 of Set 11 | verkhnyaya inta
# Processing Record 18 of Set 11 | kamina
# Processing Record 19 of Set 11 | shasta lake
# Processing Record 20 of Set 11 | salalah
# Processing Record 21 of Set 11 | tazovskiy
# Processing Record 22 of Set 11 | mahibadhoo
# Processing Record 23 of Set 11 | mirnyy
# Processing Record 24 of Set 11 | auki
# Processing Record 25 of Set 11 | neiafu
# Processing Record 26 of Set 11 | tondano
# Processing Record 27 of Set 11 | port macquarie
# Processing Record 28 of Set 11 | tecoanapa
# Processing Record 29 of Set 11 | hamilton
# Processing Record 30 of Set 11 | palafrugell
# Processing Record 31 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 11 | port hawkesbury
# Processing Record 33 of Set 11 | kieta
# Processing Record 34 of Set 11 | mastic beach
# Processing Record 35 of Set 11 | copiapo
# Processing Record 36 of Set 11 | sungaipenuh
# Processing Record 37 of Set 11 | yatou
# Processing Record 38 of Set 11 | kampong thum
# Processing Record 39 of Set 11 | abu samrah
# Processing Record 40 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 11 | flagstaff
# Processing Record 42 of Set 11 | upington
# Processing Record 43 of Set 11 | aksarka
# Processing Record 44 of Set 11 | pereira barreto
# Processing Record 45 of Set 11 | magdalena
# Processing Record 46 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 11 | nyazepetrovsk
# Processing Record 48 of Set 11 | tiksi
# Processing Record 49 of Set 11 | stokmarknes
# Processing Record 50 of Set 11 | ahipara
# Processing Record 1 of Set 12 | coffs harbour
# Processing Record 2 of Set 12 | shakawe
# Processing Record 3 of Set 12 | kurayoshi
# Processing Record 4 of Set 12 | buchanan
# Processing Record 5 of Set 12 | chara
# Processing Record 6 of Set 12 | fredericksburg
# Processing Record 7 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 8 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 9 of Set 12 | colquechaca
# Processing Record 10 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 12 | djambala
# Processing Record 12 of Set 12 | qabis
# City not found. Skipping...
# Processing Record 13 of Set 12 | fort beaufort
# Processing Record 14 of Set 12 | maputo
# Processing Record 15 of Set 12 | kortkeros
# Processing Record 16 of Set 12 | sladkovo
# Processing Record 17 of Set 12 | virtsu
# Processing Record 18 of Set 12 | santa rosa
# Processing Record 19 of Set 12 | mlowo
# Processing Record 20 of Set 12 | bartica
# Processing Record 21 of Set 12 | sinnamary
# Processing Record 22 of Set 12 | hobyo
# Processing Record 23 of Set 12 | high level
# Processing Record 24 of Set 12 | aranos
# Processing Record 25 of Set 12 | tura
# Processing Record 26 of Set 12 | saint-ambroise
# Processing Record 27 of Set 12 | bloomsburg
# Processing Record 28 of Set 12 | cacapava do sul
# Processing Record 29 of Set 12 | trincomalee
# Processing Record 30 of Set 12 | bratsk
# Processing Record 31 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 32 of Set 12 | polovinnoye
# Processing Record 33 of Set 12 | lumeje
# Processing Record 34 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 35 of Set 12 | guira de melena
# Processing Record 36 of Set 12 | kidal
# Processing Record 37 of Set 12 | nioro
# Processing Record 38 of Set 12 | plettenberg bay
# Processing Record 39 of Set 12 | presidencia roque saenz pena
# Processing Record 40 of Set 12 | dzhebariki-khaya
# Processing Record 41 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 42 of Set 12 | ondjiva
# Processing Record 43 of Set 12 | urengoy
# Processing Record 44 of Set 12 | kasama
# Processing Record 45 of Set 12 | kudahuvadhoo
# Processing Record 46 of Set 12 | lyaskelya
# Processing Record 47 of Set 12 | mayo
# Processing Record 48 of Set 12 | viramgam
# Processing Record 49 of Set 12 | elko
# Processing Record 50 of Set 12 | manzil tamim
# City not found. Skipping...
# Processing Record 1 of Set 13 | sheltozero
# Processing Record 2 of Set 13 | bonavista
# Processing Record 3 of Set 13 | ellsworth
# Processing Record 4 of Set 13 | changping
# Processing Record 5 of Set 13 | fez
# Processing Record 6 of Set 13 | inirida
# Processing Record 7 of Set 13 | makat
# Processing Record 8 of Set 13 | praxedis guerrero
# Processing Record 9 of Set 13 | kirensk
# Processing Record 10 of Set 13 | suoyarvi
# Processing Record 11 of Set 13 | tilichiki
# Processing Record 12 of Set 13 | bud
# Processing Record 13 of Set 13 | gallup
# Processing Record 14 of Set 13 | laguna
# Processing Record 15 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 16 of Set 13 | naze
# Processing Record 17 of Set 13 | beloha
# Processing Record 18 of Set 13 | zabid
# Processing Record 19 of Set 13 | ayoquezco
# City not found. Skipping...
# Processing Record 20 of Set 13 | kozan
# Processing Record 21 of Set 13 | mandalgovi
# Processing Record 22 of Set 13 | dekernes
# Processing Record 23 of Set 13 | general roca
# Processing Record 24 of Set 13 | jega
# Processing Record 25 of Set 13 | santa isabel do rio negro
# Processing Record 26 of Set 13 | merrill
# Processing Record 27 of Set 13 | swan hill
# Processing Record 28 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 29 of Set 13 | kargasok
# Processing Record 30 of Set 13 | casper
# Processing Record 31 of Set 13 | olavarria
# Processing Record 32 of Set 13 | akdepe
# Processing Record 33 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 13 | berlevag
# Processing Record 35 of Set 13 | shenjiamen
# Processing Record 36 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 13 | bacolod
# Processing Record 38 of Set 13 | reconquista
# Processing Record 39 of Set 13 | quincy
# Processing Record 40 of Set 13 | el reten
# Processing Record 41 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 13 | kupang
# Processing Record 43 of Set 13 | xinzhi
# Processing Record 44 of Set 13 | havoysund
# Processing Record 45 of Set 13 | porto recanati
# Processing Record 46 of Set 13 | okahandja
# Processing Record 47 of Set 13 | requena
# Processing Record 48 of Set 13 | madina
# Processing Record 49 of Set 13 | vagamo
# Processing Record 50 of Set 13 | muli
# Processing Record 1 of Set 14 | dori
# Processing Record 2 of Set 14 | takoradi
# Processing Record 3 of Set 14 | roald
# Processing Record 4 of Set 14 | okhotsk
# Processing Record 5 of Set 14 | mahon
# Processing Record 6 of Set 14 | kikwit
# Processing Record 7 of Set 14 | qobustan
# Processing Record 8 of Set 14 | bodden town
# Processing Record 9 of Set 14 | stockbridge
# Processing Record 10 of Set 14 | kapuskasing
# Processing Record 11 of Set 14 | khor
# Processing Record 12 of Set 14 | ellensburg
# Processing Record 13 of Set 14 | mount isa
# Processing Record 14 of Set 14 | saldanha
# Processing Record 15 of Set 14 | pangoa
# Processing Record 16 of Set 14 | grand gaube
# Processing Record 17 of Set 14 | mackenzie
# Processing Record 18 of Set 14 | fort nelson
# Processing Record 19 of Set 14 | rocha
# Processing Record 20 of Set 14 | gaoyou
# Processing Record 21 of Set 14 | berdigestyakh
# Processing Record 22 of Set 14 | gaya
# Processing Record 23 of Set 14 | ewa beach
# Processing Record 24 of Set 14 | northfield
# Processing Record 25 of Set 14 | kutum
# Processing Record 26 of Set 14 | villa de reyes
# Processing Record 27 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 28 of Set 14 | slobozia
# Processing Record 29 of Set 14 | richards bay
# Processing Record 30 of Set 14 | aleppo
# Processing Record 31 of Set 14 | pangnirtung
# Processing Record 32 of Set 14 | lumphat
# Processing Record 33 of Set 14 | banda aceh
# Processing Record 34 of Set 14 | russell
# Processing Record 35 of Set 14 | zhuhai
# Processing Record 36 of Set 14 | sola
# Processing Record 37 of Set 14 | clovis
# Processing Record 38 of Set 14 | praya
# Processing Record 39 of Set 14 | rtishchevo
# Processing Record 40 of Set 14 | grindavik
# Processing Record 41 of Set 14 | tahe
# Processing Record 42 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 14 | kozulka
# Processing Record 44 of Set 14 | pimentel
# Processing Record 45 of Set 14 | carutapera
# Processing Record 46 of Set 14 | suez
# Processing Record 47 of Set 14 | axim
# Processing Record 48 of Set 14 | cambui
# Processing Record 49 of Set 14 | kiama
# Processing Record 50 of Set 14 | puquio
# Processing Record 1 of Set 15 | tonshayevo
# Processing Record 2 of Set 15 | jalalpur
# Processing Record 3 of Set 15 | shihezi
# Processing Record 4 of Set 15 | palora
# Processing Record 5 of Set 15 | maceio
# Processing Record 6 of Set 15 | inhambane
# Processing Record 7 of Set 15 | malko tarnovo
# Processing Record 8 of Set 15 | abbeville
# Processing Record 9 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 10 of Set 15 | maragogi
# Processing Record 11 of Set 15 | felanitx
# Processing Record 12 of Set 15 | malartic
# Processing Record 13 of Set 15 | luena
# Processing Record 14 of Set 15 | trzebiatow
# Processing Record 15 of Set 15 | beyneu
# Processing Record 16 of Set 15 | hasaki
# Processing Record 17 of Set 15 | wajid
# Processing Record 18 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 19 of Set 15 | dagda
# Processing Record 20 of Set 15 | moville
# Processing Record 21 of Set 15 | hammerfest
# Processing Record 22 of Set 15 | alexandria
# Processing Record 23 of Set 15 | nhulunbuy
# Processing Record 24 of Set 15 | mayumba
# Processing Record 25 of Set 15 | severobaykalsk
# Processing Record 26 of Set 15 | savannah bight
# Processing Record 27 of Set 15 | cacador
# Processing Record 28 of Set 15 | shakhrinau
# City not found. Skipping...
# Processing Record 29 of Set 15 | vytegra
# Processing Record 30 of Set 15 | deputatskiy
# Processing Record 31 of Set 15 | howard springs
# Processing Record 32 of Set 15 | beringovskiy
# Processing Record 33 of Set 15 | faya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 675

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0        Hailar  49.2000  119.7000     68.09           clear sky        14
# 1  Puerto Ayora  -0.7393  -90.3518     71.08           clear sky        93
# 2        Bethel  41.3712  -73.4140     47.01          light rain        64
# 3       Kamenka  51.3223   42.7678     58.21           clear sky        34
# 4     Busselton -33.6500  115.3333     68.85    scattered clouds        63
# 5         Kapaa  22.0752 -159.3190     76.98    scattered clouds        84
# 6        Eureka  40.8021 -124.1637     48.92       broken clouds        76
# 7     Esperance -33.8667  121.9000     78.64     overcast clouds        40
# 8  Port Lincoln -34.7333  135.8667     59.54     overcast clouds        73
# 9       Ushuaia -54.8000  -68.3000     46.06          few clouds        57
#
#    Cloudiness  Wind Speed Country
# 0           0       14.18      CN
# 1           7        8.68      EC
# 2         100        8.05      US
# 3           1        5.44      RU
# 4          30       10.87      AU
# 5          40       16.11      US
# 6          71        1.99      US
# 7          99        4.83      AU
# 8          94        9.04      AU
# 9          20        4.61      AR

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hailar      CN  49.2000  119.7000     68.09        14           0
# 1  Puerto Ayora      EC  -0.7393  -90.3518     71.08        93           7
# 2        Bethel      US  41.3712  -73.4140     47.01        64         100
# 3       Kamenka      RU  51.3223   42.7678     58.21        34           1
# 4     Busselton      AU -33.6500  115.3333     68.85        63          30
# 5         Kapaa      US  22.0752 -159.3190     76.98        84          40
# 6        Eureka      US  40.8021 -124.1637     48.92        76          71
# 7     Esperance      AU -33.8667  121.9000     78.64        40          99
# 8  Port Lincoln      AU -34.7333  135.8667     59.54        73          94
# 9       Ushuaia      AR -54.8000  -68.3000     46.06        57          20
#
#    Wind Speed Current Description
# 0       14.18           clear sky
# 1        8.68           clear sky
# 2        8.05          light rain
# 3        5.44           clear sky
# 4       10.87    scattered clouds
# 5       16.11    scattered clouds
# 6        1.99       broken clouds
# 7        4.83     overcast clouds
# 8        9.04     overcast clouds
# 9        4.61          few clouds

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = r'C:\Users\rabbi\Desktop\ClassFolder\World_Weather_Analysis\Weather_Database\WeatherPy_Database.csv'
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
